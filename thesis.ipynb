# %%
import rasterio
import os


import numpy as np
from rasterio.plot import show



import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
img = rasterio.open("geo/clipped_geo.tif")


show(img.read(1))
# Out:
# driver :  GTiff
# dtype :  uint16
# nodata :  None
# width :  64
# height :  64
# count :  1
# crs :  None
# transform :  | 1.00, 0.00, 0.00|
# | 0.00, 1.00, 0.00|
# | 0.00, 0.00, 1.00|

# %%
img = rasterio.open("geo/clipped_mask.tif")


show(img.read(1))
# Out:
# <Axes: >
